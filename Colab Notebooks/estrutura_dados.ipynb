# %%
#Criando una lista chamada animais
animais = [1,2,3]
animais
# Out:
# [1, 2, 3]

# %%
animais = ["cahorro", "gato", 12345, 6.5]
animais
# Out:
# ['cahorro', 'gato', 12345, 6.5]

# %%
#Imprimiendo o primiero elemento da lista 
animais[0]
# Out:
# 'cahorro'

# %%
#Imprimindo 0 4 elemento da lista 
animais[3]
# Out:
# 6.5

# %%
#susbtituindo o primeiro elemento da lista 
animais[0]="papagaio"

# %%
animais
# Out:
# ['papagaio', 'gato', 12345, 6.5]

# %%
#removendo gato da lista 
animais.remove("gato")

# %%
animais
# Out:
# ['papagaio', 12345, 6.5]

# %%
len(animais)
# Out:
# 3

# %%
"gato" in animais
# Out:
# False

# %%
lista = [500, 30, 300, 80, 10]

# %%
max(lista)
# Out:
# 500

# %%
min(lista)
# Out:
# 10

# %%
animais.append("leao")

# %%
animais
# Out:
# ['papagaio', 12345, 6.5, 'leao']

# %%
animais.extend(["cobra", 6])

# %%
animais
# Out:
# ['papagaio', 12345, 6.5, 'leao', 'cobra', 6, 'cobra', 6]

# %%
animais.count("cachorro")
# Out:
# 0

# %%
lista.sort()

# %%
lista
# Out:
# [10, 30, 80, 300, 500]

# %% [markdown]
# TUPLAS

# %%
#As tuplas usam parentese como sintaxe 
tp = ("Banana", "Maca", 10, 50)

# %%
tp[0]
# Out:
# 'Banana'

# %%
#Diferente das listas as tupla imutaveis, nao pode alterar os seus elementos 
tp[0] = "Laranja"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-40-2fe3b7ece245> in <module>
#       1 #Diferente das listas as tupla imutaveis, nao pode alterar os seus elementos
# ----> 2 tp[0] = "Laranja"
#
# TypeError: 'tuple' object does not support item assignment

# %%
tp.count("Maca")
# Out:
# 1

# %% [markdown]
# **Dicionarios**

# %%
#Para criar um dicionarioa utilizamos {}
dc = {"Maca":20, "Banana":10, "Laranja":15, "Uva": 5} #Dicionarios trabalham com o conceito chave e valor

# %%
dc
# Out:
# {'Maca': 20, 'Banana': 10, 'Laranja': 15, 'Uva': 5}

# %%
#atualizando valor da Maca
dc["Maca"]=25

# %%
dc
# Out:
# {'Maca': 25, 'Banana': 10, 'Laranja': 15, 'Uva': 5}

# %%
#Retornando todas as chaves do dicionario
dc.keys()
# Out:
# dict_keys(['Maca', 'Banana', 'Laranja', 'Uva'])

# %%
dc.values()
# Out:
# dict_values([25, 10, 15, 5])

# %%
dc.setdefault("limao",22)
# Out:
# 22

# %%
dc
# Out:
# {'Maca': 25, 'Banana': 10, 'Laranja': 15, 'Uva': 5, 'limao': 22}

# %% [markdown]
# # Nova seção
